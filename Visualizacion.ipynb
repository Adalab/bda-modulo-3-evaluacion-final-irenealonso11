# %%
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
#Abrimos el csv
df = pd.read_csv("files/df_limpio.csv")

# %% [markdown]
# 1. ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?

# %%
# Agrupar los datos por mes y contar los vuelos reservados por mes
sns.regplot(x = "Flights Booked", y="Month", data = df);

# %% [markdown]
# En los meses de verano y en el mes de diciembre hay mas vuelos que en el resto de meses.

# %% [markdown]
# 2. ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente?

# %%
sns.regplot(x = "Points Accumulated", y= "Distance", data = df);

# %% [markdown]
# Claramente se ve que cuanto mas viajas mas puntos acumulados hay.

# %% [markdown]
# 3. ¿Cuál es la distribución de los clientes por provincia o estado?

# %%
sns.countplot(x= "Province", data = df );
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Hay muchos mas clientes de Ontario, British Columbia, Quebec.

# %% [markdown]
# 4. ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?

# %%
sns.barplot(x = "Education", y= "Salary", data=df, ci=None)
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# El salario anual aumenta a medidad a medida que se incremente su nivel de estudios

# %% [markdown]
# 5. ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?

# %%
# Agrupamos los datos por tipo de tarjeta y contamos las ocurrencias.
df_agrupado2 = df.groupby('Loyalty Card').size()


# Generamos una lista de colores.
colores = ["c", "cadetblue", "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen"]


# Creamos el gráfico.
plt.figure(figsize=(8, 6))
plt.pie(df_agrupado2, labels=df_agrupado2.index, autopct='%1.1f%%', colors=colores, startangle=90, textprops={'fontweight': 'bold'})


# Agregamos una leyenda.
plt.legend(title="Tipos de Tarjeta", loc='upper right', frameon=False)


# Ajustamos el aspecto del gráfico.
plt.axis('equal')  # Asegura que el gráfico sea un círculo perfecto.
plt.title('Distribución de Tipos de Tarjetas de Fidelidad', fontsize=14, color='black', weight='bold')


# Mostramos el gráfico.
plt.show()

# %% [markdown]
# La distribución de los datos indica una clara preferencia a la tarjeta llamada Star, es la más popular entre los clientes ya que representa el 45.4% del total. Esta popularidad podría deberse a que ofrece mayores beneficios.
#
# La tarjeta Nova es escogida por los clientes un 33.9%, indicando una diferencia del 11.5% en comparación con Star.
#
# La tarjeta Aurora es la menos popular de las tres opciones, representando el 20.7% del total

# %% [markdown]
# 6. ¿Cómo se distribuyen los clientes según su estado civil y género?

# %%
# Crear gráfico de barras agrupadas
sns.countplot(x='Marital Status', hue='Gender', data=df, palette=["cadetblue", "mediumseagreen"])

# Añadir etiquetas y título
plt.xlabel('Estado Civil')
plt.ylabel('Número de Clientes')
plt.title('Distribución de Clientes según Estado Civil y Género')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# En el gráfico se observa que el grupo de casados es el más numeroso, con una mayoría de hombres. Los solteros también representan un grupo considerable, con una distribución más equilibrada entre hombres y mujeres, siendo el grupo de divorciados el menos numeros
